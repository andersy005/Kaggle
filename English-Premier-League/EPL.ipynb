# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('Epl15-16.csv')

# %%
df.head()
# Out:
#   Div      Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  08/08/15  Bournemouth  Aston Villa     0     1   A     0     0   D
# 1  E0  08/08/15      Chelsea      Swansea     2     2   D     2     1   H
# 2  E0  08/08/15      Everton      Watford     2     2   D     0     1   A
# 3  E0  08/08/15    Leicester   Sunderland     4     2   H     3     0   H
# 4  E0  08/08/15   Man United    Tottenham     1     0   H     1     0   H
#
#    ...   BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
# 0  ...       1.79    26   -0.5     1.98     1.93     1.99     1.92  1.82
# 1  ...       1.99    27   -1.5     2.24     2.16     1.80     1.73  1.37
# 2  ...       1.96    26   -1.0     2.28     2.18     1.76     1.71  1.75
# 3  ...       1.67    26   -0.5     2.00     1.95     1.96     1.90  1.79
# 4  ...       2.01    26   -1.0     2.20     2.09     1.82     1.78  1.64
#
#    PSCD   PSCA
# 0  3.88   4.70
# 1  5.04  10.88
# 2  3.76   5.44
# ...

# %%
df.tail()
# Out:
#     Div      Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 375  E0  15/05/16       Stoke     West Ham     2     1   H     0     1   A
# 376  E0  15/05/16     Swansea     Man City     1     1   D     1     1   D
# 377  E0  15/05/16     Watford   Sunderland     2     2   D     0     1   A
# 378  E0  15/05/16   West Brom    Liverpool     1     1   D     1     1   D
# 379  E0  17/05/16  Man United  Bournemouth     3     1   H     1     0   H
#
#      ...  BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
# 375  ...      2.27    30   0.25     2.11     2.03     1.87     1.83  3.05
# 376  ...      2.45    31   1.00     2.14     2.05     1.85     1.81  7.05
# 377  ...      2.10    29  -0.50     2.06     2.01     1.91     1.85  1.64
# 378  ...      2.09    30  -0.25     2.10     2.05     1.86     1.81  2.61
# 379  ...      2.20    29  -0.75     1.88     1.84     2.08     2.02  1.50
#
#      PSCD  PSCA
# 375  4.00  2.26
# 376  5.00  1.47
# 377  4.52  5.27
# ...

# %%
df[['HomeTeam']]
# Out:
#            HomeTeam
# 0       Bournemouth
# 1           Chelsea
# 2           Everton
# 3         Leicester
# 4        Man United
# 5           Norwich
# 6           Arsenal
# 7         Newcastle
# 8             Stoke
# 9         West Brom
# 10      Aston Villa
# 11      Southampton
# 12       Sunderland
# 13          Swansea
# 14        Tottenham
# 15          Watford
# 16         West Ham
# 17   Crystal Palace
# 18         Man City
# 19        Liverpool
# 20   Crystal Palace
# 21        Leicester
# 22       Man United
# 23          Norwich
# 24       Sunderland
# 25         West Ham
# 26          Everton
# 27          Watford
# 28        West Brom
# 29          Arsenal
# ..              ...
# 350         Watford
# 351       West Brom
# 352      Man United
# 353     Southampton
# 354         Swansea
# 355         Chelsea
# 356     Aston Villa
# 357     Bournemouth
# 358  Crystal Palace
# 359       Leicester
# 360         Norwich
# 361      Sunderland
# 362        West Ham
# ...

# %%
pd.__version__
# Out:
# u'0.18.1'

# %%
df[df['HomeTeam'] == 'Arsenal']
# Out:
#     Div      Date HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 6    E0  09/08/15  Arsenal        West Ham     0     2   A     0     1   A
# 29   E0  24/08/15  Arsenal       Liverpool     0     0   D     0     0   D
# 40   E0  12/09/15  Arsenal           Stoke     2     0   H     1     0   H
# 77   E0  04/10/15  Arsenal      Man United     3     0   H     3     0   H
# 90   E0  24/10/15  Arsenal         Everton     2     1   H     2     1   H
# 117  E0  08/11/15  Arsenal       Tottenham     1     1   D     0     1   A
# 140  E0  05/12/15  Arsenal      Sunderland     3     1   H     1     1   D
# 169  E0  21/12/15  Arsenal        Man City     2     1   H     2     0   H
# 180  E0  28/12/15  Arsenal     Bournemouth     2     0   H     1     0   H
# 190  E0  02/01/16  Arsenal       Newcastle     1     0   H     0     0   D
# 228  E0  24/01/16  Arsenal         Chelsea     0     1   A     0     1   A
# ...
